# %%
import os
import util
from scipy import sparse
import numpy as np
from collections import Counter
import pandas as py
from matplotlib import pyplot as plt

try:
    import xml.etree.cElementTree as ET
except ImportError:
    import xml.etree.ElementTree as ET

def check_all(start_index, end_index, direc):
    classes = []
    ids = [] 
    processes = []
    i = -1
    for datafile in os.listdir(direc):
        if datafile == '.DS_Store':
            continue

        i += 1
        if i < start_index:
            continue 
        if i >= end_index:
            break
        
        # extract id and true class (if available) from filename
        id_str, clazz = datafile.split('.')[:2]
        ids.append(id_str)
        # add target class if this is training data
        try:
            classes.append(util.malware_classes.index(clazz))

        except ValueError:
            # we should only fail to find the label in our list of malware classes
            # if this is test data, which always has an "X" label
            assert clazz == "X"
            classes.append(-1)

        tree = ET.parse(os.path.join(direc,datafile))
        
        processList = []
        for el in tree.iter() :
            processList.append(el.tag)
        processes.append(processList)

    return np.array(classes), ids, processes

# %%
import pandas as pd 

y, ids, processes = check_all(0, 3086, 'train')
lengths = [len(process) for process in processes]

df = pd.DataFrame()
df['class'] = y
df['ids'] = ids
df['lengths'] = lengths

# %%
def contains_sublist(lst, sublst):
    n = len(sublst)
    return any([(sublst == lst[i:i+n]) for i in xrange(len(lst)-n+1)])

def substring(n,m,minLength=5) :
    start = 0
    while start < len(n) - 5 :
        exists = True
        while exists == True and (start + minLength) < len(n):
            exists = contains_sublist(m, n[start:start+minLength])
            minLength += 1
        start += 1
    return minLength/float(len(n))

def most_common(lst):
    return max(set(lst), key=lst.count)

def capMask(vector, limit) :
    if np.sum(vector) > limit :
        falseMask = random.sample(np.where(np.array(mask) == True)[0].tolist(),np.sum(vector) - limit)
        for sample in falseMask :
            vector[sample] = False
        return vector
    else :
        return vector

def bestMatch(unknown, allProcesses, lengths, y, df, minLength, error) :
    u_length = len(unknown)
    mask = [True if (length-error) <= u_length <= (length+error) else False for length in lengths]
    
    if np.sum(mask) == 1 :
        return [el[1] for el in zip(mask,y) if el[0] == True][0]
    elif u_length < 1500 :
        mask = capMask(mask, 50)
        dftouse = df[mask]
        processtouse = [el[1] for el in zip(mask,allProcesses) if el[0] == True]

        withScores = dftouse.copy()
        withScores['scores'] = [substring(unknown, process) for process in processtouse]
        topClasses = withScores[withScores.scores > 0.8].sort(['scores'], ascending=False)['class'].tolist()
        return most_common(topClasses)
    else :
        return 'Too hard! :('

# %%
for i in range(100) :
    u_length = len(processes[i])
    mask = [True if (length-error) <= u_length <= (length+error) else False for length in lengths]
    print np.sum(mask)
# Out:
# (728, 2)
# (12137, 1)
# (97, 236)
# (484, 1)
# (1136, 3)
# (23, 5)
# (716, 24)
# (1313, 2)
# (713, 30)
# (702, 99)
# (702, 99)
# (715, 21)
# (77, 5)
# (9926, 1)
# (631, 8)
# (28, 2)
# (706, 132)
# (936, 1)
# (709, 44)
# (117, 2)
# (7301, 1)
# (97, 236)
# (2909, 1)
# (716, 24)
# (634, 11)
# (1342, 1)
# (706, 132)
# (705, 63)
# (2027, 1)
# (7132, 1)
# (40, 43)
# (561, 1)
# (704, 10)
# (57, 7)
# (97, 236)
# (192, 11)
# (3593, 1)
# (709, 44)
# (75, 4)
# (702, 99)
# (8251, 1)
# (1456, 26)
# (6756, 1)
# (97, 236)
# (294, 1)
# (1456, 26)
# (87, 5)
# (560, 1)
# (705, 63)
# (358, 1)
# (706, 132)
# (2304, 1)
# (714, 52)
# (196, 2)
# (637, 14)
# (12985, 1)
# (81, 5)
# (89, 5)
# (90, 3)
# (710, 48)
# (805, 1)
# (1736, 6)
# (9591, 1)
# (717, 13)
# (709, 44)
# (722, 14)
# (281, 1)
# (190, 2)
# (703, 32)
# (1268, 2)
# (39, 6)
# (712, 37)
# (97, 236)
# (713, 30)
# (714, 52)
# (708, 25)
# (1370, 1)
# (292, 2)
# (712, 37)
# (6876, 1)
# (707, 56)
# (710, 48)
# (97, 236)
# (109, 14)
# (723, 12)
# (97, 236)
# (635, 8)
# (707, 56)
# (1221, 1)
# (9730, 1)
# (708, 25)
# (709, 44)
# (710, 48)
# (1503, 3)
# (43, 1)
# (504, 2)
# (642, 7)
# (1194, 2)
# (4292, 1)
# (707, 56)

# %%
for i in range(0,100) :
    print "Actual: " + str(y[i])
    print "Pred: " + str(bestMatch(processes[i], processes, lengths, y, df, minLength=5, error=0))
    print ""
# Out:
# Actual: 8
# Pred: 8
#
# Actual: 6
# Pred: 6
#
# Actual: 12
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-236-2276c1d8e124> in <module>()
#       1 for i in range(0,100) :
#       2     print "Actual: " + str(y[i])
# ----> 3     print "Pred: " + str(bestMatch(processes[i], processes, lengths, y, df, minLength=5, error=0))
#       4     print ""
#
# <ipython-input-235-6d13d62d97f4> in bestMatch(unknown, allProcesses, lengths, y, df, minLength, error)
#      32         return [el[1] for el in zip(mask,y) if el[0] == True][0]
#      33     elif u_length < 1500 :
# ---> 34         mask = capMask(mask, 50)
#      35         dftouse = df[mask]
#      36         processtouse = [el[1] for el in zip(mask,allProcesses) if el[0] == True]
#
# <ipython-input-235-6d13d62d97f4> in capMask(vector, limit)
#      18 def capMask(vector, limit) :
#      19     if np.sum(vector) > limit :
# ---> 20         falseMask = random.sample(np.where(np.array(mask) == True)[0].tolist(),np.sum(vector) - limit)
#      21         for sample in falseMask :
#      22             vector[sample] = False
#
# //anaconda/lib/python2.7/random.pyc in sample(self, population, k)
#     321         n = len(population)
#     322         if not 0 <= k <= n:
# --> 323             raise ValueError("sample larger than population")
#     324         random = self.random
#     325         _int = int
#
# ValueError: sample larger than population

# %%
u_length = len(processes[2])
mask = [True if (length-error) <= u_length <= (length+error) else False for length in lengths]
new_mask = capMask(mask, 50)
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  ...]

# %%
new_mask = capMask(mask, 50)
np.sum(new_mask)
# Out:
# 50

# %%
processes[0:100]
# Out:
# [['processes',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'open_file',
#   'get_windows_directory',
#   'check_for_debugger',
#   'load_dll',
#   'get_system_directory',
#   'open_key',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'open_key',
#   'query_value',
#   'query_value',
#   'get_system_directory',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'set_windows_hook',
#   'set_windows_hook',
#   'open_key',
#   'query_value',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'load_dll',
#   'get_system_directory',
#   'create_window',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'get_system_directory',
#   'load_dll',
#   'create_window',
#   'load_dll',
#   'load_dll',
#   'create_window',
#   'get_system_directory',
#   'find_window',
#   'enum_window',
#   'create_window',
#   'show_window',
#   'enum_window',
#   'show_window',
#   'open_key',
#   'query_value',
#   'query_value',
#   'open_key',
#   'open_key',
#   'create_mutex',
#   'get_system_directory',
#   'enum_window',
#   'get_file_attributes',
#   'create_window',
#   'create_window',
#   'create_window',
#   'show_window',
#   'enum_window',
#   'show_window',
#   'enum_window',
#   'get_system_directory',
#   'enum_window',
#   'get_file_attributes',
#   'get_file_attributes',
#   'create_directory',
#   'get_file_attributes',
#   'create_directory',
#   'get_file_attributes',
#   'create_directory',
#   'get_file_attributes',
#   'create_directory',
#   'create_window',
#   'create_window',
#   'load_dll',
#   'create_window',
#   'enum_window',
#   'show_window',
#   'enum_window',
#   'show_window',
#   'create_thread',
#   'sleep',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'sleep',
#   'create_window',
#   'load_dll',
#   'open_file',
#   'get_file_attributes',
#   'find_file',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_file',
#   'load_dll',
#   'com_create_instance',
#   'get_system_directory',
#   'get_file_attributes',
#   'open_file',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'open_file',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'create_thread',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'open_key',
#   'open_key',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'open_file',
#   'com_create_instance',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'enum_values',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'find_file',
#   'get_system_directory',
#   'find_file',
#   'get_windows_directory',
#   'find_file',
#   'get_windows_directory',
#   'find_file',
#   'com_get_class_object',
#   'load_dll',
#   'open_file',
#   'get_file_attributes',
#   'get_file_attributes',
#   'load_dll',
#   'get_system_directory',
#   'get_file_attributes',
#   'open_file',
#   'load_dll',
#   'open_file',
#   'open_file',
#   'open_key',
#   'open_key',
#   'query_value',
#   'open_file',
#   'open_file',
#   'find_file',
#   'open_key',
#   'open_key',
#   'open_key',
#   'load_dll',
#   'load_dll',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'create_process',
#   'kill_process',
#   'enum_window',
#   'thread',
#   'all_section',
#   'create_file',
#   'open_file',
#   'set_file_time',
#   'set_file_attributes',
#   'create_file',
#   'open_file',
#   'set_file_time',
#   'set_file_attributes',
#   'get_system_directory',
#   'load_dll',
#   'thread',
#   'all_section',
#   'sleep',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'thread',
#   'all_section',
#   'load_dll',
#   'check_for_debugger',
#   'load_dll',
#   'load_dll',
#   'open_key',
#   'load_dll',
#   'get_system_directory',
#   'get_file_attributes',
#   'open_file',
#   'load_dll',
#   'load_dll',
#   'open_process',
#   'open_process',
#   'kill_process'],
#  ['processes',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'create_thread',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'check_for_debugger',
#   'load_dll',
#   'get_system_directory',
#   'open_key',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'open_key',
#   'query_value',
#   'query_value',
#   'get_system_directory',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'set_windows_hook',
#   'set_windows_hook',
#   'create_window',
#   'load_dll',
#   'load_dll',
#   'get_system_directory',
#   'get_file_attributes',
#   'open_file',
#   'create_directory',
#   'delete_file',
#   'create_file',
#   'open_key',
#   'open_key',
#   'query_value',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'get_file_attributes',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'get_file_attributes',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'get_file_attributes',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'get_file_attributes',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'get_file_attributes',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'get_file_attributes',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'get_file_attributes',
#   'find_file',
#   'create_mutex',
#   'open_file',
#   'create_key',
#   'create_key',
#   'delete_value',
#   'delete_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'get_system_directory',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'load_dll',
#   'get_system_directory',
#   'create_window',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'get_system_directory',
#   'load_dll',
#   'create_window',
#   'load_dll',
#   'find_file',
#   'delete_file',
#   'create_directory',
#   'get_file_attributes',
#   'create_directory',
#   'get_file_attributes',
#   'create_directory',
#   'get_file_attributes',
#   'create_directory',
#   'get_file_attributes',
#   'create_directory',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'set_file_attributes',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'create_window',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'destroy_window',
#   'find_window',
#   'enum_window',
#   'create_window',
#   'show_window',
#   'enum_window',
#   'show_window',
#   'open_key',
#   'query_value',
#   'query_value',
#   'open_key',
#   'open_key',
#   'create_mutex',
#   'get_system_directory',
#   'destroy_window',
#   'enum_window',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'destroy_window',
#   'read_value',
#   'read_value',
#   'read_value',
#   'read_value',
#   'read_value',
#   'read_value',
#   'get_system_directory',
#   'read_section',
#   'find_window',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'find_window',
#   'open_process',
#   'create_mutex',
#   'find_window',
#   'open_process',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'open_file',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'destroy_window',
#   'enum_window',
#   'find_window',
#   'open_process',
#   'find_window',
#   'open_process',
#   'destroy_window',
#   'enum_window',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'destroy_window',
#   'get_system_directory',
#   'find_window',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'find_window',
#   'open_process',
#   'find_window',
#   'open_process',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'set_file_attributes',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'set_file_attributes',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'set_file_attributes',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'set_file_attributes',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'open_file',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'destroy_window',
#   'enum_window',
#   'find_window',
#   'open_process',
#   'find_window',
#   'open_process',
#   'destroy_window',
#   'enum_window',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'destroy_window',
#   'create_window',
#   'find_window',
#   'create_thread',
#   'find_window',
#   'open_process',
#   'enum_window',
#   'find_window',
#   'enum_window',
#   'get_system_directory',
#   'find_window',
#   'open_process',
#   'find_window',
#   'get_system_directory',
#   'find_window',
#   'open_process',
#   'enum_window',
#   'get_system_directory',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'find_window',
#   'open_process',
#   'find_window',
#   'get_system_directory',
#   'find_window',
#   'open_process',
#   'enum_window',
#   'get_system_directory',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'find_window',
#   'open_process',
#   'enum_window',
#   'find_window',
#   'get_system_directory',
#   'find_window',
#   'open_process',
#   'enum_window',
#   'find_window',
#   'open_process',
#   'enum_window',
#   'find_window',
#   'open_process',
#   'enum_window',
#   'get_system_directory',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'find_window',
#   'open_process',
#   'find_window',
#   'get_system_directory',
#   'find_window',
#   'open_process',
#   'get_system_directory',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'find_window',
#   'get_system_directory',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'find_window',
#   'get_system_directory',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'open_key',
#   'set_value',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'get_file_attributes',
#   'create_file',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'get_file_attributes',
#   'create_file',
#   'load_dll',
#   'get_file_attributes',
#   'get_file_attributes',
#   'open_key',
#   'query_value',
#   'com_create_instance',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'enum_values',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'get_file_attributes',
#   'load_dll',
#   'load_dll',
#   'open_file',
#   'open_file',
#   'open_key',
#   'open_key',
#   'query_value',
#   'open_file',
#   'open_file',
#   'find_file',
#   'open_key',
#   'open_key',
#   'open_key',
#   'create_process',
#   'destroy_window',
#   'get_system_directory',
#   'enum_window',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'get_file_attributes',
#   'find_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'find_file',
#   'get_file_attributes',
#   'set_file_attributes',
#   'remove_directory',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'kill_process',
#   'enum_window',
#   'thread',
#   'all_section',
#   'open_file',
#   'open_key',
#   'open_key',
#   'delete_value',
#   'delete_value',
#   'set_value',
#   'set_value',
#   'set_value',
#   'set_value',
#   'set_value',
#   'delete_value',
#   'delete_value',
#   'delete_value',
#   'delete_value',
#   'delete_value',
#   'delete_value',
#   'delete_value',
#   'delete_value',
#   'delete_value',
#   'delete_value',
#   'delete_value',
#   'delete_value',
#   'set_value',
#   'set_value',
#   'delete_value',
#   'delete_value',
#   'open_key',
#   'get_system_directory',
#   'open_file',
#   'get_system_directory',
#   'open_file',
#   'open_file',
#   'open_key',
#   'open_key',
#   'delete_value',
#   'delete_value',
#   'set_value',
#   'set_value',
#   'set_value',
#   'set_value',
#   'set_value',
#   ...],
#  ['processes',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'check_for_debugger',
#   'load_dll',
#   'get_system_directory',
#   'open_key',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'open_key',
#   'query_value',
#   'query_value',
#   'get_system_directory',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'set_windows_hook',
#   'set_windows_hook',
#   'create_window',
#   'load_dll',
#   'open_key',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'load_dll',
#   'get_system_directory',
#   'create_window',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'get_system_directory',
#   'load_dll',
#   'create_window',
#   'show_window',
#   'open_key',
#   'set_windows_hook',
#   'create_window',
#   'open_key',
#   'load_dll',
#   'get_username',
#   'load_dll',
#   'get_system_directory',
#   'create_file',
#   'find_file',
#   'create_directory',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'open_key',
#   'open_key',
#   'read_value',
#   'open_key',
#   'open_key',
#   'read_value',
#   'get_file_attributes',
#   'get_windows_directory',
#   'get_file_attributes',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'destroy_window',
#   'enum_window',
#   'sleep',
#   'enum_window',
#   'kill_process',
#   'get_system_directory',
#   'load_dll',
#   'enum_window'],
#  ['processes',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'check_for_debugger',
#   'load_dll',
#   'get_system_directory',
#   'open_key',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'open_key',
#   'query_value',
#   'query_value',
#   'get_system_directory',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'set_windows_hook',
#   'set_windows_hook',
#   'open_key',
#   'query_value',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'load_dll',
#   'get_system_directory',
#   'create_window',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'get_system_directory',
#   'load_dll',
#   'create_window',
#   'create_window',
#   'get_system_directory',
#   'enum_window',
#   'create_window',
#   'get_system_directory',
#   'find_window',
#   'enum_window',
#   'create_window',
#   'show_window',
#   'load_dll',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'load_dll',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'query_value',
#   'open_key',
#   'open_key',
#   'create_mutex',
#   'get_system_directory',
#   'destroy_window',
#   'enum_window',
#   'get_windows_directory',
#   'get_system_directory',
#   'delete_file',
#   'open_key',
#   'query_value',
#   'get_system_time',
#   'get_system_time',
#   'create_window',
#   'load_dll',
#   'get_file_attributes',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'get_file_attributes',
#   'revert_to_self',
#   'create_file',
#   'set_file_time',
#   'get_file_attributes',
#   'set_file_attributes',
#   'delete_file',
#   'move_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'open_key',
#   'query_value',
#   'create_file',
#   'get_system_time',
#   'open_file',
#   'open_key',
#   'open_key',
#   'query_value',
#   'load_dll',
#   'create_window',
#   'load_dll',
#   'get_system_directory',
#   'get_file_attributes',
#   'open_file',
#   'load_dll',
#   'load_dll',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'enum_window',
#   'load_dll',
#   'create_window',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'enum_window',
#   'load_dll',
#   'open_key',
#   'open_key',
#   'get_file_attributes',
#   'get_file_attributes',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'get_file_attributes',
#   'create_window',
#   'enum_window',
#   'show_window',
#   'enum_window',
#   'show_window',
#   'find_window',
#   'open_process',
#   'create_mutex',
#   'create_file',
#   'set_file_time',
#   'get_windows_directory',
#   'get_system_directory',
#   'open_file',
#   'get_windows_directory',
#   'get_system_directory',
#   'open_file',
#   'open_file',
#   'open_file',
#   'open_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'set_file_attributes',
#   'get_file_attributes',
#   'get_file_attributes',
#   'load_dll',
#   'load_dll',
#   'get_file_attributes',
#   'get_file_attributes',
#   'create_file',
#   'move_file',
#   'move_file',
#   'delete_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'open_key',
#   'query_value',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'open_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'open_file',
#   'load_dll',
#   'get_file_attributes',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'get_file_attributes',
#   'create_file',
#   'set_file_time',
#   'get_windows_directory',
#   'get_system_directory',
#   'open_file',
#   'get_windows_directory',
#   'get_system_directory',
#   'open_file',
#   'open_file',
#   'open_file',
#   'open_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'set_file_attributes',
#   'get_file_attributes',
#   'get_file_attributes',
#   'get_file_attributes',
#   'create_file',
#   'move_file',
#   'move_file',
#   'delete_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'open_key',
#   'query_value',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'open_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'find_file',
#   'open_file',
#   'load_dll',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'create_directory',
#   'load_dll',
#   'create_window',
#   'com_create_instance',
#   'get_system_directory',
#   'get_file_attributes',
#   'open_file',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'query_value',
#   'load_dll',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'load_dll',
#   'enum_share',
#   'open_file',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_file',
#   'open_file',
#   'get_computer_name',
#   'get_file_attributes',
#   'create_file',
#   'open_process',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'load_dll',
#   'load_dll',
#   'open_file',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'read_value',
#   'get_file_attributes',
#   'open_process',
#   'enum_window',
#   'create_window',
#   'get_system_directory',
#   'enum_window',
#   'show_window',
#   'enum_window',
#   'show_window',
#   'find_window',
#   'open_process',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll'],
#  ['processes',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'check_for_debugger',
#   'load_dll',
#   'get_system_directory',
#   'open_key',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'open_key',
#   'query_value',
#   'query_value',
#   'get_system_directory',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'set_windows_hook',
#   'set_windows_hook',
#   'create_window',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'create_process',
#   'open_file',
#   'vm_allocate',
#   'vm_protect',
#   'vm_write',
#   'vm_allocate',
#   'vm_protect',
#   'vm_protect',
#   'vm_write',
#   'vm_protect',
#   'vm_protect',
#   'vm_write',
#   'vm_allocate',
#   'vm_protect',
#   'vm_protect',
#   'vm_write',
#   'vm_allocate',
#   'vm_protect',
#   'vm_protect',
#   'vm_write',
#   'vm_allocate',
#   'vm_allocate',
#   'vm_protect',
#   'create_thread_remote',
#   'vm_allocate',
#   'vm_allocate',
#   'vm_protect',
#   'create_thread_remote',
#   'enum_window',
#   'kill_process',
#   'enum_window',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'thread',
#   'all_section',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'check_for_debugger',
#   'load_dll',
#   'get_system_directory',
#   'open_key',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'open_key',
#   'query_value',
#   'query_value',
#   'get_system_directory',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'set_windows_hook',
#   'set_windows_hook',
#   'create_window',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'create_open_file',
#   'create_open_file',
#   'create_open_file',
#   'open_file',
#   'load_dll',
#   'get_system_directory',
#   'get_computer_name',
#   'create_mutex',
#   'get_username',
#   'open_file',
#   'get_username',
#   'com_create_instance',
#   'get_system_directory',
#   'get_file_attributes',
#   'open_file',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'open_file',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'create_thread',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'open_key',
#   'open_key',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'load_dll',
#   'com_get_class_object',
#   'open_file',
#   'get_computer_name',
#   'create_thread',
#   'load_dll',
#   'create_thread',
#   'com_create_instance',
#   'open_file',
#   'com_create_instance',
#   'load_dll',
#   'open_key',
#   'load_dll',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'query_value',
#   'open_file',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'query_value',
#   'open_file',
#   'open_key',
#   'query_value',
#   'com_get_class_object',
#   'query_value',
#   'open_file',
#   'create_thread',
#   'get_username',
#   'create_thread',
#   'get_username',
#   'open_file',
#   'sleep',
#   'open_key',
#   'query_value',
#   'get_system_directory',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'load_dll',
#   'get_system_directory',
#   'create_window',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'get_system_directory',
#   'load_dll',
#   'create_window',
#   'get_system_directory',
#   'get_computer_name',
#   'create_open_file',
#   'create_open_file',
#   'create_open_file',
#   'create_open_file',
#   'get_system_time',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'create_socket',
#   'create_open_file',
#   'get_host_by_name',
#   'open_key',
#   'query_value',
#   'create_socket',
#   'create_thread',
#   'connect_socket',
#   'message',
#   'send_socket',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'message',
#   'send_socket',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'trimmed_bytes',
#   'message',
#   'recv_socket',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'trimmed_bytes',
#   'com_create_instance',
#   'open_key',
#   'load_dll',
#   'load_dll',
#   'create_open_file',
#   'create_open_file',
#   'get_system_time',
#   'create_socket',
#   'create_open_file',
#   'get_host_by_name',
#   'create_socket',
#   'connect_socket',
#   'message',
#   'send_socket',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'message',
#   'send_socket',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'trimmed_bytes',
#   'message',
#   'send_socket',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'trimmed_bytes',
#   'message',
#   'send_socket',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'trimmed_bytes',
#   'message',
#   'send_socket',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'trimmed_bytes',
#   'message',
#   'send_socket',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'dump_line',
#   'trimmed_bytes',
#   'message',
#   'send_socket',
#   'dump_line',
#   'dump_line',
# ...
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   ...],
#  ['processes',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'open_file',
#   'check_for_debugger',
#   'load_dll',
#   'get_system_directory',
#   'open_key',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'create_mutex',
#   'open_key',
#   'query_value',
#   'query_value',
#   'get_system_directory',
#   'open_key',
#   'query_value',
#   'create_mutex',
#   'set_windows_hook',
#   'set_windows_hook',
#   'open_key',
#   'query_value',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'get_system_directory',
#   'load_dll',
#   'load_dll',
#   'get_system_directory',
#   'create_window',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'get_system_directory',
#   'load_dll',
#   'create_window',
#   'load_dll',
#   'load_dll',
#   'create_window',
#   'get_system_directory',
#   'find_window',
#   'enum_window',
#   'create_window',
#   'show_window',
#   'enum_window',
#   'show_window',
#   'open_key',
#   'query_value',
#   'query_value',
#   'open_key',
#   'open_key',
#   'create_mutex',
#   'get_system_directory',
#   'enum_window',
#   'get_file_attributes',
#   'create_window',
#   'create_window',
#   'load_dll',
#   'create_window',
#   'enum_window',
#   'show_window',
#   'enum_window',
#   'show_window',
#   'create_thread',
#   'sleep',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'sleep',
#   'create_window',
#   'load_dll',
#   'open_file',
#   'get_file_attributes',
#   'find_file',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_file',
#   'load_dll',
#   'com_create_instance',
#   'get_system_directory',
#   'get_file_attributes',
#   'open_file',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'open_file',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'create_thread',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'open_key',
#   'open_key',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'load_dll',
#   'open_key',
#   'query_value',
#   'open_file',
#   'com_create_instance',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'vm_protect',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'enum_values',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'enum_keys',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'open_key',
#   'query_value',
#   'query_value',
#   'query_value',
#   'query_value',
#   'find_file',
#   'get_system_directory',
#   'find_file',
#   'get_windows_directory',
#   'find_file',
#   'get_windows_directory',
#   'find_file',
#   'com_get_class_object',
#   'load_dll',
#   'open_file',
#   'get_file_attributes',
#   'get_file_attributes',
#   'load_dll',
#   'get_system_directory',
#   'get_file_attributes',
#   'open_file',
#   'load_dll',
#   'open_file',
#   'open_file',
#   'open_key',
#   'open_key',
#   'query_value',
#   'open_file',
#   'open_file',
#   'find_file',
#   'open_key',
#   'open_key',
#   'open_key',
#   'load_dll',
#   'load_dll',
#   'open_key',
#   'open_key',
#   'open_key',
#   'open_key',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'enum_window',
#   'destroy_window',
#   'create_process',
#   'kill_process',
#   'enum_window',
#   'thread',
#   'all_section',
#   'create_file',
#   'open_file',
#   'set_file_time',
#   'set_file_attributes',
#   'create_file',
#   'open_file',
#   'set_file_time',
#   'set_file_attributes',
#   'get_system_directory',
#   'load_dll',
#   'thread',
#   'all_section',
#   'sleep',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'process',
#   'thread',
#   'all_section',
#   'load_image',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'load_dll',
#   'thread',
#   'all_section',
#   'load_dll',
#   'check_for_debugger',
#   'load_dll',
#   'load_dll',
#   'open_key',
#   'load_dll',
#   'get_system_directory',
#   'get_file_attributes',
#   'open_file',
#   'open_process',
#   'open_process',
#   'kill_process']]
